# %%
#Movie Data Correlation Analysis by Jesumbo Joseph Oludipe

#What are the factors affecting gross revenue of a movie? actors? genres? user ratings? budget? company? dirctor?
#This project entails an analysis of Movie data over the last few decades. 
#There are 6820 movies in the dataset (220 movies per year, 1986-2016).
#The data was original scrapped from IMDB by Daniel Grijalva (Kaggle).


#Import libraries and packages
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

#Adjust configuration of plots
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

#Read in the data

df = pd.read_csv(r'C:\Users\Oludipe j\Documents\Data Analysis\Data Analysis with Pandas and Pythons\pandas\Python\movies.csv')

# %%
#Exploring the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#
#

# %%
#Checking for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#Removing rows with missing values

df=df.dropna()

# %%
df.head(2)
# Out:
#               name rating      genre  year                       released  \
# 0      The Shining      R      Drama  1980  June 13, 1980 (United States)
# 1  The Blue Lagoon      R  Adventure  1980   July 2, 1980 (United States)
#
#    score     votes         director                   writer            star  \
# 0    8.4  927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8   65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
#
#           country      budget       gross            company  runtime
# 0  United Kingdom  19000000.0  46998772.0       Warner Bros.    146.0
# 1   United States   4500000.0  58853106.0  Columbia Pictures    104.0

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
#Checking data types

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Remove decimals in Budget, Votes, and Gross revenue

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

df['votes'] = df['votes'].astype('int64')

# %%
# Checking for Outliers

df.boxplot(column=['gross'])
# Out:
# <AxesSubplot: >

# %%
#Create correct year column

df['released'] = df['released'].str.split('(').str[0]

df['yearcorrect'] = df['released'].astype(str).str.strip().str[-4:]

df.head(3)
# Out:
#                    name rating   genre  year            released  score  \
# 5445             Avatar  PG-13  Action  2009  December 18, 2009     7.8
# 7445  Avengers: Endgame  PG-13  Action  2019     April 26, 2019     8.4
# 3045            Titanic  PG-13   Drama  1997  December 19, 1997     7.8
#
#         votes       director              writer               star  \
# 5445  1100000  James Cameron       James Cameron    Sam Worthington
# 7445   903000  Anthony Russo  Christopher Markus  Robert Downey Jr.
# 3045  1100000  James Cameron       James Cameron  Leonardo DiCaprio
#
#             country     budget       gross                company  runtime  \
# 5445  United States  237000000  2847246203  Twentieth Century Fox    162.0
# 7445  United States  356000000  2797501328         Marvel Studios    181.0
# 3045  United States  200000000  2201647264  Twentieth Century Fox    194.0
#
#      yearcorrect
# 5445        2009
# 7445        2019
# 3045        1997

# %%
#Order by Gross Revenue

df = df.sort_values(by=['gross'], inplace=False, ascending=False)
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                 released  score    votes       director              writer  \
# 5445  December 18, 2009     7.8  1100000  James Cameron       James Cameron
# 7445     April 26, 2019     8.4   903000  Anthony Russo  Christopher Markus
# 3045  December 19, 1997     7.8  1100000  James Cameron       James Cameron
# 6663  December 18, 2015     7.8   876000    J.J. Abrams     Lawrence Kasdan
# 7244     April 27, 2018     8.4   897000  Anthony Russo  Christopher Markus
#
#                    star        country     budget       gross  \
# ...

# %%
#Remove duplicates

df.drop_duplicates()

df.head(3)
# Out:
#                    name rating   genre  year            released  score  \
# 5445             Avatar  PG-13  Action  2009  December 18, 2009     7.8
# 7445  Avengers: Endgame  PG-13  Action  2019     April 26, 2019     8.4
# 3045            Titanic  PG-13   Drama  1997  December 19, 1997     7.8
#
#         votes       director              writer               star  \
# 5445  1100000  James Cameron       James Cameron    Sam Worthington
# 7445   903000  Anthony Russo  Christopher Markus  Robert Downey Jr.
# 3045  1100000  James Cameron       James Cameron  Leonardo DiCaprio
#
#             country     budget       gross                company  runtime  \
# 5445  United States  237000000  2847246203  Twentieth Century Fox    162.0
# 7445  United States  356000000  2797501328         Marvel Studios    181.0
# 3045  United States  200000000  2201647264  Twentieth Century Fox    194.0
#
#      yearcorrect
# 5445        2009
# 7445        2019
# 3045        1997

# %%
#Checking correllation between Gross Revenue and other fields

# %%
#Gross Revenue and Budget
#Scatter plot of budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for Film')

plt.show()

# %%
#Plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"red"}, line_kws={"color":'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Determining correlation between all numeric columns

#Pearson correlation

df.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
#High correlation betweeen budget and gross revenue

#Visualizing the Correlation Matrix

correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numerical Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
#Gross Revenue and other fields

#Converting strings to numbers for correlation calculations

df_numerized = df.copy()

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       496    7.8  1100000       785    1263
# 7445   388       5      0  2019       124    8.4   903000       105     513
# 3045  4909       5      6  1997       502    7.8  1100000       785    1263
# 6663  3643       5      0  2015       498    7.8   876000       768    1806
# 7244   389       5      0  2018       132    8.4   897000       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  1534       47  237000000  2847246203     1382    162.0           29
# 7445  1470       47  356000000  2797501328      983    181.0           39
# 3045  1073       47  200000000  2201647264     1382    194.0           17
# 6663   356       47  245000000  2069521700      945    138.0           35
# 7244  1470       47  321000000  2048359754      983    149.0           38

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                 released  score    votes       director              writer  \
# 5445  December 18, 2009     7.8  1100000  James Cameron       James Cameron
# 7445     April 26, 2019     8.4   903000  Anthony Russo  Christopher Markus
# 3045  December 19, 1997     7.8  1100000  James Cameron       James Cameron
# 6663  December 18, 2015     7.8   876000    J.J. Abrams     Lawrence Kasdan
# 7244     April 27, 2018     8.4   897000  Anthony Russo  Christopher Markus
#
#                    star        country     budget       gross  \
# ...

# %%
#Visualizing the Correlation Matrix

correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numerical Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006155  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.017349  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.021321  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001888  0.056386
# released    -0.006155  0.017349  0.021321 -0.001888  1.000000  0.046091
# score        0.014450  0.065983  0.035106  0.056386  0.046091  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.029593  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002481  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008145  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015558  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017043 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.021144  0.072001
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')

corr_pairs = correlation_matrix.unstack()

corr_pairs['gross']
# Out:
# name           0.005639
# rating        -0.181906
# genre         -0.244101
# year           0.274321
# released       0.009643
# score          0.222556
# votes          0.614751
# director      -0.029560
# writer        -0.035885
# star          -0.000004
# country        0.060078
# budget         0.740247
# gross          1.000000
# company        0.149553
# runtime        0.275796
# yearcorrect    0.268721
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(ascending=False)
sorted_pairs['gross']
# Out:
# gross          1.000000
# budget         0.740247
# votes          0.614751
# runtime        0.275796
# year           0.274321
# yearcorrect    0.268721
# score          0.222556
# company        0.149553
# country        0.060078
# released       0.009643
# name           0.005639
# star          -0.000004
# director      -0.029560
# writer        -0.035885
# rating        -0.181906
# genre         -0.244101
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr.tail(4)
# Out:
# budget  gross     0.740247
# gross   budget    0.740247
#         votes     0.614751
# votes   gross     0.614751
# dtype: float64

# %%
#Budget and Votes has the highest correlation to Gross Revenue

#Company name, genre, director, etc., has little correlation to Gross Revenue

# %%
#Strip plot of Rating vs Gross revenue

sns.stripplot(x="rating", y="gross", data=df)
# Out:
# <AxesSubplot: xlabel='rating', ylabel='gross'>

# %%
#
#
# The top 15 companies by Gross Revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 54610959970
# Universal Pictures           51241105418
# Columbia Pictures            42356430218
# Paramount Pictures           40021704691
# Twentieth Century Fox        39542573303
# Walt Disney Pictures         35833650748
# New Line Cinema              19612851164
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Dreamworks Pictures          11593807697
# Touchstone Pictures          10664679494
# Metro-Goldwyn-Mayer (MGM)     8937010092
# Summit Entertainment          8318570396
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7243673721
# Name: gross, dtype: int64
